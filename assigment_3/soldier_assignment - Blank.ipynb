# %%
#pip install pyforest

# %% [markdown]
# The 2012 US Army Anthropometric Survey (ANSUR II) was executed by the Natick Soldier Research, Development and Engineering Center (NSRDEC) from October 2010 to April 2012 and is comprised of personnel representing the total US Army force to include the US Army Active Duty, Reserves, and National Guard. In addition to the anthropometric and demographic data described below, the ANSUR II database also consists of 3D whole body, foot, and head scans of Soldier participants. These 3D data are not publicly available out of respect for the privacy of ANSUR II participants. The data from this survey are used for a wide range of equipment design, sizing, and tariffing applications within the military and has many potential commercial, industrial, and academic applications.
#
# The ANSUR II working databases contain 93 anthropometric measurements which were directly measured, and 15 demographic/administrative variables explained below. The ANSUR II Male working database contains a total sample of 4,082 subjects. The ANSUR II Female working database contains a total sample of 1,986 subjects.
#
#
# data dict:
# https://data.world/datamil/ansur-ii-data-dictionary/workspace/file?filename=ANSUR+II+Databases+Overview.pdf

# %% [markdown]
# Hİnt for metric : Our mission to classify soldiers races via their body sclales. We want a balanced score for our predictions.

# %% [markdown]
# # Import libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# # Ingest the data from links below and make a dataframe
# - Soldiers Male : https://query.data.world/s/h3pbhckz5ck4rc7qmt2wlknlnn7esr
# - Soldiers Female : https://query.data.world/s/sq27zz4hawg32yfxksqwijxmpwmynq

# %%
df_m = pd.read_csv("male.csv", encoding="Windows-1252")
df_f = pd.read_csv("female.csv")

# %% [markdown]
# # EDA
# Tips :
# - Drop unnecessary colums
# - Drop DODRace class if value count below 500 (we assume that our data model can't learn if it is below 500)
# - Find unusual value in Weightlbs

# %%
df_m.head(3)
# Out:
#    subjectid  abdominalextensiondepthsitting  acromialheight  \
# 0      10027                             266            1467
# 1      10032                             233            1395
# 2      10033                             287            1430
#
#    acromionradialelength  anklecircumference  axillaheight  \
# 0                    337                 222          1347
# 1                    326                 220          1293
# 2                    341                 230          1327
#
#    balloffootcircumference  balloffootlength  biacromialbreadth  \
# 0                      253               202                401
# 1                      245               193                394
# 2                      256               196                427
#
#    bicepscircumferenceflexed  bicristalbreadth  bideltoidbreadth  \
# 0                        369               274               493
# 1                        338               257               479
# ...

# %%
df_f.head(3)
# Out:
#    SubjectId  abdominalextensiondepthsitting  acromialheight  \
# 0      10037                             231            1282
# 1      10038                             194            1379
# 2      10042                             183            1369
#
#    acromionradialelength  anklecircumference  axillaheight  \
# 0                    301                 204          1180
# 1                    320                 207          1292
# 2                    329                 233          1271
#
#    balloffootcircumference  balloffootlength  biacromialbreadth  \
# 0                      222               177                373
# 1                      225               178                372
# 2                      237               196                397
#
#    bicepscircumferenceflexed  bicristalbreadth  bideltoidbreadth  \
# 0                        315               263               466
# 1                        272               250               430
# ...

# %%
print(df_m.shape,df_f.shape)
# Out:
# (4082, 108) (1986, 108)

# %% [markdown]
# # DATA Preprocessing

# %%
df_m.columns = df_m.columns.str.lower()
df_f.columns = df_f.columns.str.lower()

# %%
df_f.columns
# Out:
# Index(['subjectid', 'abdominalextensiondepthsitting', 'acromialheight',
#        'acromionradialelength', 'anklecircumference', 'axillaheight',
#        'balloffootcircumference', 'balloffootlength', 'biacromialbreadth',
#        'bicepscircumferenceflexed',
#        ...
#        'branch', 'primarymos', 'subjectsbirthlocation', 'subjectnumericrace',
#        'ethnicity', 'dodrace', 'age', 'heightin', 'weightlbs',
#        'writingpreference'],
#       dtype='object', length=108)

# %%
frame = [df_m,df_f]

# %%
df = pd.concat(frame)

# %%
df.shape
# Out:
# (6068, 108)

# %%
# target sütununa göz atalım.
# Drop DODRace class if value count below 500 (we assume that our data model can't learn if it is below 500)
df['dodrace'].value_counts()
# Out:
# 1    3792
# 2    1298
# 3     679
# 4     188
# 6      59
# 5      49
# 8       3
# Name: dodrace, dtype: int64

# %%
df = df[df['dodrace'].isin([1,2,3])]

# %%
df_n = df.select_dtypes(include= 'int') # Numeric columns selection
df_c = df.select_dtypes(include='object') # Categorical columns selection

df.columns
# Out:
# Index(['subjectid', 'abdominalextensiondepthsitting', 'acromialheight',
#        'acromionradialelength', 'anklecircumference', 'axillaheight',
#        'balloffootcircumference', 'balloffootlength', 'biacromialbreadth',
#        'bicepscircumferenceflexed',
#        ...
#        'branch', 'primarymos', 'subjectsbirthlocation', 'subjectnumericrace',
#        'ethnicity', 'dodrace', 'age', 'heightin', 'weightlbs',
#        'writingpreference'],
#       dtype='object', length=108)

# %%
df.shape
# Out:
# (5769, 108)

# %%
df.describe(include='object').T
# Out:
#                       count unique                     top  freq
# gender                 5769      2                    Male  3899
# date                   5769    253                5-Apr-12    43
# installation           5769     12             Camp Shelby  1111
# component              5769      3            Regular Army  2955
# branch                 5769      3  Combat Service Support  3021
# primarymos             5769    281                     11B   641
# subjectsbirthlocation  5769    136              California   417
# ethnicity              1125    157                 Mexican   356
# writingpreference      5769      3              Right hand  5088

# %%
# gender hariç tüm categorik sütunları düşelim. 
print(df_c.columns[1:])
df = df.drop(df_c.columns[1:],axis=1)
# Out:
# Index(['date', 'installation', 'component', 'branch', 'primarymos',
#        'subjectsbirthlocation', 'ethnicity', 'writingpreference'],
#       dtype='object')

# %%
df.head()
# Out:
#    subjectid  abdominalextensiondepthsitting  acromialheight  \
# 0      10027                             266            1467
# 1      10032                             233            1395
# 2      10033                             287            1430
# 3      10092                             234            1347
# 4      10093                             250            1585
#
#    acromionradialelength  anklecircumference  axillaheight  \
# 0                    337                 222          1347
# 1                    326                 220          1293
# 2                    341                 230          1327
# 3                    310                 230          1239
# 4                    372                 247          1478
#
#    balloffootcircumference  balloffootlength  biacromialbreadth  \
# 0                      253               202                401
# 1                      245               193                394
# ...

# %%
# şimdi de numerik sütunlarımızı inceleyelim
df.head(3)
# Out:
#    subjectid  abdominalextensiondepthsitting  acromialheight  \
# 0      10027                             266            1467
# 1      10032                             233            1395
# 2      10033                             287            1430
#
#    acromionradialelength  anklecircumference  axillaheight  \
# 0                    337                 222          1347
# 1                    326                 220          1293
# 2                    341                 230          1327
#
#    balloffootcircumference  balloffootlength  biacromialbreadth  \
# 0                      253               202                401
# 1                      245               193                394
# 2                      256               196                427
#
#    bicepscircumferenceflexed  bicristalbreadth  bideltoidbreadth  \
# 0                        369               274               493
# 1                        338               257               479
# ...

# %%
# ilk bakışta düşmeye karar verdiğim sütunlar:
# ['subjectid', 'age','weightkg']

# %%
df.drop(['subjectid', 'age','weightkg'],axis=1,inplace=True)

# %%
# gender sütununu dummy yapalım

# %%
df = pd.get_dummies(df,drop_first=True)

# %%
df.describe().T
# Out:
#                                  count         mean         std     min  \
# abdominalextensiondepthsitting  5769.0   247.254290   37.457748   155.0
# acromialheight                  5769.0  1408.630265   78.303123  1146.0
# acromionradialelength           5769.0   328.071590   20.444554   249.0
# anklecircumference              5769.0   225.201768   15.965783   156.0
# axillaheight                    5769.0  1301.902583   71.260913  1062.0
# balloffootcircumference         5769.0   244.408043   16.803556   186.0
# balloffootlength                5769.0   195.118911   13.379000   151.0
# biacromialbreadth               5769.0   399.706015   30.124094   283.0
# bicepscircumferenceflexed       5769.0   341.663027   41.270615   216.0
# bicristalbreadth                5769.0   274.903449   19.239580   197.0
# bideltoidbreadth                5769.0   491.454845   42.011888   357.0
# bimalleolarbreadth              5769.0    72.335413    5.326965    55.0
# ...

# %%
for i in df.columns:
    plt.figure(figsize=(8,5))
    sns.boxplot(data = df, y = i)
# Out:
# C:\Users\JOSEPH~1\AppData\Local\Temp/ipykernel_15712/890802518.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure(figsize=(8,5))

# %%
# yukarıda yer alan boxplot grafiklerini inceleyerek kaba taslak en absürt dataları belirleyelim.
['weightlbs']

# %%
sns.boxplot(data = df, x = 'weightlbs')
# Out:
# <AxesSubplot:xlabel='weightlbs'>

# %%
df[df.weightlbs == 0]
# 0 lbs ağırlığı yanlış ölçüm.
# Out:
#      abdominalextensiondepthsitting  acromialheight  acromionradialelength  \
# 866                             241            1462                    329
#
#      anklecircumference  axillaheight  balloffootcircumference  \
# 866                 230          1334                      248
#
#      balloffootlength  biacromialbreadth  bicepscircumferenceflexed  \
# 866               201                418                        404
#
#      bicristalbreadth  bideltoidbreadth  bimalleolarbreadth  bitragionchinarc  \
# 866               274               549                  75               343
#
#      bitragionsubmandibulararc  bizygomaticbreadth  buttockcircumference  \
# 866                        316                 136                  1047
#
#      buttockdepth  buttockheight  buttockkneelength  buttockpopliteallength  \
# 866           253            887                615                     501
#
#      calfcircumference  cervicaleheight  chestbreadth  chestcircumference  \
# ...

# %%
df = df.drop(866,axis=0)

# %% [markdown]
# # Modelling Implementing
# - You can use pipeline (optional)
# - You can research over/undersampling methods and after selecting the best model, examine it to see if better scores can be obtained. (https://imbalanced-learn.org/stable/introduction.html)

# %%
from sklearn.pipeline import Pipeline

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from xgboost import XGBClassifier
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# %%
logistic = [("scaler", MinMaxScaler()), ("logistic", LogisticRegression())]

# %% [markdown]
# ## 1. Logistic Regression

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# ## 2. Support Vector Classifier

# %% [markdown]
# ## 3. Random Forest

# %% [markdown]
# ## 4. XGBoost

# %% [markdown]
# # Choose the best model based on the metric you choose and make a random prediction

# %% [markdown]
# ---
# ---
